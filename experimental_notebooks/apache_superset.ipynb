# %%
import sys
sys.path
if 'f:\\Users\\hassa\\carecognitics_backend' not in sys.path:
    sys.path.append('f:\\Users\\hassa\\carecognitics_backend')

# %%
import requests
import json
from IPython.display import JSON
from configs import request_post_chart

# %%
#configs
base_url = 'http://localhost:8088'
#base_url ='http://carecognitics-superset.31g.co.uk'

# %%
payload = {'username':'admin',
           'password':'admin',
           'provider':'db',
           'refresh': 'True'
           }
r = requests.post(base_url + '/api/v1/security/login', json=payload)

# %%
print(r.status_code)
# Out:
# 200

# %%
access_token = r.json()['access_token']
refresh_token = r.json()['refresh_token']
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJmcmVzaCI6dHJ1ZSwiaWF0IjoxNzE2ODkzMDk0LCJqdGkiOiI1OTE3OTk4My05MjcyLTQ5ZWQtYmRmNC00NDk1MmVjYjJhMjciLCJ0eXBlIjoiYWNjZXNzIiwic3ViIjoxLCJuYmYiOjE3MTY4OTMwOTQsImV4cCI6MTcxNjg5Mzk5NH0.fO6L-tASvfgRfe0M3mlponIugvwwSEIKmquAUv0PjY4'

# %%
headersAuth = {'Authorization':'Bearer ' + access_token}
headersAuth
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJmcmVzaCI6dHJ1ZSwiaWF0IjoxNzE2ODkzMDk0LCJqdGkiOiI1OTE3OTk4My05MjcyLTQ5ZWQtYmRmNC00NDk1MmVjYjJhMjciLCJ0eXBlIjoiYWNjZXNzIiwic3ViIjoxLCJuYmYiOjE3MTY4OTMwOTQsImV4cCI6MTcxNjg5Mzk5NH0.fO6L-tASvfgRfe0M3mlponIugvwwSEIKmquAUv0PjY4'}

# %% [markdown]
# ### CSRF Token

# %%
csrf_request=requests.get(base_url + '/api/v1/security/csrf_token/', headers=headersAuth)
csrf_token=csrf_request.json()['result']
print(csrf_request.status_code)
print(csrf_token)
# Out:
# 200
# IjBmY2I5YzMwYmIyZmVhZGYyYzRlM2RlNjI1NzA3MDFiNzA1ZWNjMjki.ZlWthw.kAZz1lT21PKS1fqmX4n6kFUPgXI

# %% [markdown]
# ## API Flow

# %%
dbs_r = requests.get(base_url+'/api/v1/database/', headers=headersAuth)
dbs = dbs_r.json()

# %%
db_ids = {}
for db in dbs['result']:
    db_ids[db['database_name']] = db['id']
print(db_ids)
# Out:
# {'chinook': 5, 'examples': 1}

# %%
db_scr = requests.get(base_url+f"/api/v1/database/{db_ids['chinook']}/schemas/", headers=headersAuth)
db_sc = db_scr.json()
db_sc
# Out:
# {'result': ['information_schema', 'public']}

# %% [markdown]
# ### create chart from dataset

# %%
# datasource_name = table_name
# null = None
# r2=requests.post(base_url+'/api/v1/chart/', headers=headersAuth, json={"cache_timeout": null,
#       "certification_details": null,
#       "certified_by": null,
#       "dashboards": [],
#       "datasource_id": excecuted_data_id,
#       "datasource_name": datasource_name,
#       "datasource_type": excecuted_data_type,
#       "description": 'null',
#       "params": """{\"datasource\":\"25__table\",\"viz_type\":\"echarts_timeseries_bar\",\"x_axis\":\"genre\",\"time_grain_sqla\":\"P1D\",\"xAxisForceCategorical\":false,
#       \"x_axis_sort_asc\":true,\"x_axis_sort_series\":\"name\",\"x_axis_sort_series_ascending\":true,\"metrics\":[{\"expressionType\":\"SIMPLE\",\"column\":{\"advanced_data_type\":null,
#       \"certification_details\":null,\"certified_by\":null,\"column_name\":\"jp_sales\",\"description\":null,
#       \"expression\":null,\"filterable\":true,\"groupby\":true,\"id\":null,\"is_certified\":false,\"is_dttm\":false,\"python_date_format\":null,\"type\":\"FLOAT\",\"type_generic\":0,
#       \"verbose_name\":null,\"warning_markdown\":null},\"aggregate\":\"SUM\",\"sqlExpression\":null,\"datasourceWarning\":false,\"hasCustomLabel\":false,\"label\":\"Total Sales Cost in Japan\",
#       \"optionName\":\"metric_na7nqv3jwcd_znuzdhquag\"},{\"expressionType\":\"SIMPLE\",\"column\":{\"advanced_data_type\":null,\"certification_details\":null,\"certified_by\":null,
#       \"column_name\":\"eu_sales\",\"description\":null,\"expression\":null,\"filterable\":true,\"groupby\":true,\"id\":null,\"is_certified\":false,\"is_dttm\":false,\"python_date_format\":null,
#       \"type\":\"FLOAT\",\"type_generic\":0,\"verbose_name\":null,\"warning_markdown\":null},\"aggregate\":\"SUM\",\"sqlExpression\":null,\"datasourceWarning\":false,\"hasCustomLabel\":false,
#       \"label\":\"Total Sales Cost in the EU\",\"optionName\":\"metric_ztiitd2b78q_1v0gmbvii2u\"}],\"groupby\":[],\"adhoc_filters\":[],\"order_desc\":true,\"row_limit\":10000,\"truncate_metric\":true,
#       \"show_empty_columns\":true,\"comparison_type\":\"values\",\"annotation_layers\":[],\"forecastPeriods\":10,\"forecastInterval\":0.8,\"orientation\":\"vertical\",\"x_axis_title_margin\":15,
#       \"y_axis_title_margin\":15,\"y_axis_title_position\":\"Left\",\"sort_series_type\":\"sum\",\"color_scheme\":\"supersetColors\",\"only_total\":true,\"show_legend\":true,
#       \"legendType\":\"scroll\",\"legendOrientation\":\"top\",\"x_axis_time_format\":\"smart_date\",\"y_axis_format\":\"SMART_NUMBER\",\"truncateXAxis\":true,\"y_axis_bounds\":[null,null],
#       \"rich_tooltip\":true,\"tooltipTimeFormat\":\"smart_date\",\"extra_form_data\":{},\"dashboards\":[]}""",
#       "slice_name": "Popularity for Total Sales of Different video game genres",
#        "viz_type": "echarts_timeseries_bar"}
#               )
# r2.json()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel '.venv (Python 3.11.2)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### visualize chart

# %%
chart = requests.get(base_url+'/api/v1/chart/', headers=headersAuth)
chart.json()
# Out:
# {'count': 98,
#  'description_columns': {},
#  'ids': [695,
#   694,
#   692,
#   687,
#   693,
#   690,
#   689,
#   691,
#   686,
#   677,
#   683,
#   684,
#   682,
#   676,
#   681,
#   675,
#   678,
#   680,
#   679,
#   666],
#  'label_columns': {'cache_timeout': 'Cache Timeout',
#   'certification_details': 'Certification Details',
#   'certified_by': 'Certified By',
#   'changed_by.first_name': 'Changed By First Name',
#   'changed_by.last_name': 'Changed By Last Name',
#   'changed_by_name': 'Changed By Name',
#   'changed_on_delta_humanized': 'Changed On Delta Humanized',
#   'changed_on_dttm': 'Changed On Dttm',
#   'changed_on_utc': 'Changed On Utc',
#   'created_by.first_name': 'Created By First Name',
#   'created_by.id': 'Created By Id',
#   'created_by.last_name': 'Created By Last Name',
#   'created_by_name': 'Created By Name',
#   'created_on_delta_humanized': 'Created On Delta Humanized',
#   'dashboards.dashboard_title': 'Dashboards Dashboard Title',
#   'dashboards.id': 'Dashboards Id',
#   'datasource_id': 'Datasource Id',
#   'datasource_name_text': 'Datasource Name Text',
#   'datasource_type': 'Datasource Type',
#   'datasource_url': 'Datasource Url',
#   'description': 'Description',
#   'description_markeddown': 'Description Markeddown',
#   'edit_url': 'Edit Url',
#   'form_data': 'Form Data',
#   'id': 'Id',
#   'is_managed_externally': 'Is Managed Externally',
#   'last_saved_at': 'Last Saved At',
#   'last_saved_by.first_name': 'Last Saved By First Name',
#   'last_saved_by.id': 'Last Saved By Id',
#   'last_saved_by.last_name': 'Last Saved By Last Name',
#   'owners.first_name': 'Owners First Name',
#   'owners.id': 'Owners Id',
#   'owners.last_name': 'Owners Last Name',
#   'params': 'Params',
#   'slice_name': 'Slice Name',
#   'slice_url': 'Slice Url',
#   'table.default_endpoint': 'Table Default Endpoint',
#   'table.table_name': 'Table Table Name',
#   'tags.id': 'Tags Id',
#   'tags.name': 'Tags Name',
#   'tags.type': 'Tags Type',
#   'thumbnail_url': 'Thumbnail Url',
#   'url': 'Url',
#   'viz_type': 'Viz Type'},
#  'list_columns': ['is_managed_externally',
#   'certified_by',
#   'certification_details',
#   'cache_timeout',
#   'changed_by.first_name',
#   'changed_by.last_name',
#   'changed_by_name',
#   'changed_on_delta_humanized',
#   'changed_on_dttm',
#   'changed_on_utc',
#   'created_by.first_name',
#   'created_by.id',
#   'created_by.last_name',
#   'created_by_name',
#   'created_on_delta_humanized',
#   'datasource_id',
#   'datasource_name_text',
#   'datasource_type',
#   'datasource_url',
#   'description',
#   'description_markeddown',
#   'edit_url',
#   'form_data',
#   'id',
#   'last_saved_at',
#   'last_saved_by.id',
#   'last_saved_by.first_name',
#   'last_saved_by.last_name',
#   'owners.first_name',
#   'owners.id',
#   'owners.last_name',
#   'dashboards.id',
#   'dashboards.dashboard_title',
#   'params',
#   'slice_name',
#   'slice_url',
#   'table.default_endpoint',
#   'table.table_name',
#   'thumbnail_url',
#   'url',
#   'viz_type',
#   'tags.id',
#   'tags.name',
#   'tags.type'],
#  'list_title': 'List Slice',
#  'order_columns': ['changed_by.first_name',
#   'changed_on_delta_humanized',
#   'datasource_id',
#   'datasource_name',
#   'last_saved_at',
#   'last_saved_by.id',
#   'last_saved_by.first_name',
#   'last_saved_by.last_name',
#   'slice_name',
#   'viz_type'],
#  'result': [{'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '16 minutes ago',
#    'changed_on_dttm': 1716891062896.081,
#    'changed_on_utc': '2024-05-28T10:11:02.896081+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '20 minutes ago',
#    'dashboards': [],
#    'datasource_id': 4,
#    'datasource_name_text': 'public.birth_france_by_region',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=4',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/695',
#    'form_data': {'datasource': '4__table',
#     'entity': 'DEPT_ID',
#     'granularity_sqla': '',
#     'metric': {'aggregate': 'AVG',
#      'column': {'column_name': '2004', 'type': 'INT'},
#      'expressionType': 'SIMPLE',
#      'label': 'Boys',
#      'optionName': 'metric_112342'},
#     'row_limit': 500000,
#     'select_country': 'france',
#     'slice_id': 695,
#     'time_range': ' : ',
#     'viz_type': 'country_map'},
#    'id': 695,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "entity": "DEPT_ID",\n    "granularity_sqla": "",\n    "metric": {\n        "aggregate": "AVG",\n        "column": {\n            "column_name": "2004",\n            "type": "INT"\n        },\n        "expressionType": "SIMPLE",\n        "label": "Boys",\n        "optionName": "metric_112342"\n    },\n    "row_limit": 500000,\n    "select_country": "france",\n    "since": "",\n    "until": "",\n    "viz_type": "country_map"\n}',
#    'slice_name': 'Birth in France by department in 2016',
#    'slice_url': '/explore/?slice_id=695&form_data=%7B%22slice_id%22%3A%20695%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_france_by_region'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/695/thumbnail/79fad41abb05b2206b12599d65164ee4/',
#    'url': '/explore/?slice_id=695',
#    'viz_type': 'country_map'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '16 minutes ago',
#    'changed_on_dttm': 1716891062895.172,
#    'changed_on_utc': '2024-05-28T10:11:02.895172+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '20 minutes ago',
#    'dashboards': [],
#    'datasource_id': 3,
#    'datasource_name_text': 'public.long_lat',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=3',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/694',
#    'form_data': {'all_columns': ['occupancy'],
#     'all_columns_x': 'LON',
#     'all_columns_y': 'LAT',
#     'datasource': '3__table',
#     'granularity_sqla': 'day',
#     'mapbox_style': 'mapbox://styles/mapbox/light-v9',
#     'row_limit': 500000,
#     'slice_id': 694,
#     'time_range': '2014-01-01 : now',
#     'viz_type': 'mapbox'},
#    'id': 694,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "all_columns": [\n        "occupancy"\n    ],\n    "all_columns_x": "LON",\n    "all_columns_y": "LAT",\n    "granularity_sqla": "day",\n    "mapbox_style": "mapbox://styles/mapbox/light-v9",\n    "row_limit": 500000,\n    "since": "2014-01-01",\n    "until": "now",\n    "viz_type": "mapbox"\n}',
#    'slice_name': 'Mapbox Long/Lat',
#    'slice_url': '/explore/?slice_id=694&form_data=%7B%22slice_id%22%3A%20694%7D',
#    'table': {'default_endpoint': None, 'table_name': 'long_lat'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/694/thumbnail/59b4879430a20f827ecd170955d1869f/',
#    'url': '/explore/?slice_id=694',
#    'viz_type': 'mapbox'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891006016.164,
#    'changed_on_utc': '2024-05-28T10:10:06.016164+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '20 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/692',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'girl',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metric': 'sum__num',
#     'row_limit': 50000,
#     'slice_id': 692,
#     'subheader': 'total female participants',
#     'time_range': '100 years ago : now',
#     'viz_type': 'big_number_total'},
#    'id': 692,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "girl",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metric": "sum__num",\n    "row_limit": 50000,\n    "subheader": "total female participants",\n    "time_range": "100 years ago : now",\n    "viz_type": "big_number_total"\n}',
#    'slice_name': 'Number of Girls',
#    'slice_url': '/explore/?slice_id=692&form_data=%7B%22slice_id%22%3A%20692%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/692/thumbnail/8c74bc4aa9a56d9c890c357e7a6a9ae1/',
#    'url': '/explore/?slice_id=692',
#    'viz_type': 'big_number_total'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891005924.3381,
#    'changed_on_utc': '2024-05-28T10:10:05.924338+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/687',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'row_limit': 50000,
#     'slice_id': 687,
#     'time_range': '100 years ago : now',
#     'viz_type': 'line'},
#    'id': 687,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "line"\n}',
#    'slice_name': 'Num Births Trend',
#    'slice_url': '/explore/?slice_id=687&form_data=%7B%22slice_id%22%3A%20687%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/687/thumbnail/5938d6bea36cee6e2af5a713d2acc00a/',
#    'url': '/explore/?slice_id=687',
#    'viz_type': 'line'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891003510.207,
#    'changed_on_utc': '2024-05-28T10:10:03.510207+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '20 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/693',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'groupbyColumns': ['state'],
#     'groupbyRows': ['name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'row_limit': 50000,
#     'slice_id': 693,
#     'time_range': '100 years ago : now',
#     'viz_type': 'pivot_table_v2'},
#    'id': 693,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "groupbyColumns": [\n        "state"\n    ],\n    "groupbyRows": [\n        "name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "pivot_table_v2"\n}',
#    'slice_name': 'Pivot Table',
#    'slice_url': '/explore/?slice_id=693&form_data=%7B%22slice_id%22%3A%20693%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/693/thumbnail/73a680f43060c74ef4706acd7ce425d7/',
#    'url': '/explore/?slice_id=693',
#    'viz_type': 'pivot_table_v2'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891003121.5752,
#    'changed_on_utc': '2024-05-28T10:10:03.121575+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/690',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': '10',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num_california',
#        'expression': "CASE WHEN state = 'CA' THEN num ELSE 0 END"},
#       'expressionType': 'SIMPLE',
#       'label': 'SUM(num_california)'}],
#     'row_limit': 50000,
#     'slice_id': 690,
#     'time_range': '100 years ago : now',
#     'timeseries_limit_metric': {'aggregate': 'SUM',
#      'column': {'column_name': 'num_california',
#       'expression': "CASE WHEN state = 'CA' THEN num ELSE 0 END"},
#      'expressionType': 'SIMPLE',
#      'label': 'SUM(num_california)'},
#     'viz_type': 'line'},
#    'id': 690,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": "10",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num_california",\n                "expression": "CASE WHEN state = \'CA\' THEN num ELSE 0 END"\n            },\n            "expressionType": "SIMPLE",\n            "label": "SUM(num_california)"\n        }\n    ],\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "timeseries_limit_metric": {\n        "aggregate": "SUM",\n        "column": {\n            "column_name": "num_california",\n            "expression": "CASE WHEN state = \'CA\' THEN num ELSE 0 END"\n        },\n        "expressionType": "SIMPLE",\n        "label": "SUM(num_california)"\n    },\n    "viz_type": "line"\n}',
#    'slice_name': 'Top 10 California Names Timeseries',
#    'slice_url': '/explore/?slice_id=690&form_data=%7B%22slice_id%22%3A%20690%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/690/thumbnail/f6b3557a258273acedc84ea5668bdc19/',
#    'url': '/explore/?slice_id=690',
#    'viz_type': 'line'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891001758.933,
#    'changed_on_utc': '2024-05-28T10:10:01.758933+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/689',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metric': {'aggregate': 'SUM',
#      'column': {'column_name': 'num_california',
#       'expression': "CASE WHEN state = 'CA' THEN num ELSE 0 END"},
#      'expressionType': 'SIMPLE',
#      'label': 'SUM(num_california)'},
#     'row_limit': 50000,
#     'slice_id': 689,
#     'time_range': '100 years ago : now',
#     'viz_type': 'big_number_total'},
#    'id': 689,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metric": {\n        "aggregate": "SUM",\n        "column": {\n            "column_name": "num_california",\n            "expression": "CASE WHEN state = \'CA\' THEN num ELSE 0 END"\n        },\n        "expressionType": "SIMPLE",\n        "label": "SUM(num_california)"\n    },\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "big_number_total"\n}',
#    'slice_name': 'Number of California Births',
#    'slice_url': '/explore/?slice_id=689&form_data=%7B%22slice_id%22%3A%20689%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/689/thumbnail/09ca76160babcbe6d31f930f778b8e98/',
#    'url': '/explore/?slice_id=689',
#    'viz_type': 'big_number_total'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '17 minutes ago',
#    'changed_on_dttm': 1716891000498.454,
#    'changed_on_utc': '2024-05-28T10:10:00.498454+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '20 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/691',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'row_limit': 50,
#     'slice_id': 691,
#     'time_range': '100 years ago : now',
#     'timeseries_limit_metric': {'aggregate': 'SUM',
#      'column': {'column_name': 'num_california',
#       'expression': "CASE WHEN state = 'CA' THEN num ELSE 0 END"},
#      'expressionType': 'SIMPLE',
#      'label': 'SUM(num_california)'},
#     'viz_type': 'table'},
#    'id': 691,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "row_limit": 50,\n    "time_range": "100 years ago : now",\n    "timeseries_limit_metric": {\n        "aggregate": "SUM",\n        "column": {\n            "column_name": "num_california",\n            "expression": "CASE WHEN state = \'CA\' THEN num ELSE 0 END"\n        },\n        "expressionType": "SIMPLE",\n        "label": "SUM(num_california)"\n    },\n    "viz_type": "table"\n}',
#    'slice_name': 'Names Sorted by Num in California',
#    'slice_url': '/explore/?slice_id=691&form_data=%7B%22slice_id%22%3A%20691%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/691/thumbnail/d09d94a865e57aec9469055b7cf77cce/',
#    'url': '/explore/?slice_id=691',
#    'viz_type': 'table'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890944822.875,
#    'changed_on_utc': '2024-05-28T10:09:04.822875+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/686',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'AVG',
#       'column': {'column_name': 'num', 'type': 'BIGINT(20)'},
#       'expressionType': 'SIMPLE',
#       'label': 'AVG(num)',
#       'optionName': 'metric_vgops097wej_g8uff99zhk7'}],
#     'metrics_b': ['sum__num'],
#     'row_limit': 50000,
#     'slice_id': 686,
#     'time_range': '100 years ago : now',
#     'viz_type': 'mixed_timeseries',
#     'yAxisIndex': 0,
#     'yAxisIndexB': 1},
#    'id': 686,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "AVG",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT(20)"\n            },\n            "expressionType": "SIMPLE",\n            "label": "AVG(num)",\n            "optionName": "metric_vgops097wej_g8uff99zhk7"\n        }\n    ],\n    "metrics_b": [\n        "sum__num"\n    ],\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "mixed_timeseries",\n    "yAxisIndex": 0,\n    "yAxisIndexB": 1\n}',
#    'slice_name': 'Average and Sum Trends',
#    'slice_url': '/explore/?slice_id=686&form_data=%7B%22slice_id%22%3A%20686%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/686/thumbnail/9d57641cd2761957a3b3fe863cd1a2b1/',
#    'url': '/explore/?slice_id=686',
#    'viz_type': 'mixed_timeseries'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890943999.2212,
#    'changed_on_utc': '2024-05-28T10:09:03.999221+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/677',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'rich_tooltip': True,
#     'row_limit': 50000,
#     'show_legend': True,
#     'slice_id': 677,
#     'time_range': '100 years ago : now',
#     'viz_type': 'line'},
#    'id': 677,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "rich_tooltip": true,\n    "row_limit": 50000,\n    "show_legend": true,\n    "time_range": "100 years ago : now",\n    "viz_type": "line"\n}',
#    'slice_name': 'Trends',
#    'slice_url': '/explore/?slice_id=677&form_data=%7B%22slice_id%22%3A%20677%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/677/thumbnail/76192e58483d7b91b774461464b035de/',
#    'url': '/explore/?slice_id=677',
#    'viz_type': 'line'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890943963.277,
#    'changed_on_utc': '2024-05-28T10:09:03.963277+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/683',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'girl',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'comparison_type': 'values',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': 10,
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'row_limit': 50000,
#     'slice_id': 683,
#     'stacked_style': 'expand',
#     'time_grain_sqla': 'P1D',
#     'time_range': '100 years ago : now',
#     'viz_type': 'area',
#     'x_axis_forma': 'smart_date'},
#    'id': 683,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "girl",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "comparison_type": "values",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": 10,\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "row_limit": 50000,\n    "stacked_style": "expand",\n    "time_grain_sqla": "P1D",\n    "time_range": "100 years ago : now",\n    "viz_type": "area",\n    "x_axis_forma": "smart_date"\n}',
#    'slice_name': 'Top 10 Girl Name Share',
#    'slice_url': '/explore/?slice_id=683&form_data=%7B%22slice_id%22%3A%20683%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/683/thumbnail/53a50245a0f65085283fa85263be0437/',
#    'url': '/explore/?slice_id=683',
#    'viz_type': 'area'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890943346.1821,
#    'changed_on_utc': '2024-05-28T10:09:03.346182+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/684',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'boy',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'comparison_type': 'values',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': 10,
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num', 'type': 'BIGINT'},
#       'expressionType': 'SIMPLE',
#       'label': 'Births',
#       'optionName': 'metric_11'}],
#     'row_limit': 50000,
#     'slice_id': 684,
#     'stacked_style': 'expand',
#     'time_grain_sqla': 'P1D',
#     'time_range': '100 years ago : now',
#     'viz_type': 'area',
#     'x_axis_forma': 'smart_date'},
#    'id': 684,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "boy",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "comparison_type": "values",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": 10,\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num",\n                "type": "BIGINT"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Births",\n            "optionName": "metric_11"\n        }\n    ],\n    "row_limit": 50000,\n    "stacked_style": "expand",\n    "time_grain_sqla": "P1D",\n    "time_range": "100 years ago : now",\n    "viz_type": "area",\n    "x_axis_forma": "smart_date"\n}',
#    'slice_name': 'Top 10 Boy Name Share',
#    'slice_url': '/explore/?slice_id=684&form_data=%7B%22slice_id%22%3A%20684%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/684/thumbnail/328677a1853b9eb10f9397aec35f7a40/',
#    'url': '/explore/?slice_id=684',
#    'viz_type': 'area'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890943292.779,
#    'changed_on_utc': '2024-05-28T10:09:03.292779+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/682',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'boy',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '100',
#     'markup_type': 'markdown',
#     'metric': 'sum__num',
#     'rotation': 'square',
#     'row_limit': 50000,
#     'series': 'name',
#     'size_from': '10',
#     'size_to': '70',
#     'slice_id': 682,
#     'time_range': '100 years ago : now',
#     'viz_type': 'word_cloud'},
#    'id': 682,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "boy",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "100",\n    "markup_type": "markdown",\n    "metric": "sum__num",\n    "rotation": "square",\n    "row_limit": 50000,\n    "series": "name",\n    "size_from": "10",\n    "size_to": "70",\n    "time_range": "100 years ago : now",\n    "viz_type": "word_cloud"\n}',
#    'slice_name': 'Boy Name Cloud',
#    'slice_url': '/explore/?slice_id=682&form_data=%7B%22slice_id%22%3A%20682%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/682/thumbnail/4f84329f379b2ade17af9cf2a37d5eaf/',
#    'url': '/explore/?slice_id=682',
#    'viz_type': 'word_cloud'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890943203.0088,
#    'changed_on_utc': '2024-05-28T10:09:03.203009+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/676',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['gender'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metric': 'sum__num',
#     'row_limit': 50000,
#     'slice_id': 676,
#     'time_range': '100 years ago : now',
#     'viz_type': 'pie'},
#    'id': 676,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "gender"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metric": "sum__num",\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "pie"\n}',
#    'slice_name': 'Genders',
#    'slice_url': '/explore/?slice_id=676&form_data=%7B%22slice_id%22%3A%20676%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/676/thumbnail/5c8e5ed9f491b3bb7d8613721d2ec233/',
#    'url': '/explore/?slice_id=676',
#    'viz_type': 'pie'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890939150.975,
#    'changed_on_utc': '2024-05-28T10:08:59.150975+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/681',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'boy',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': ['sum__num'],
#     'row_limit': 50,
#     'slice_id': 681,
#     'time_range': '100 years ago : now',
#     'timeseries_limit_metric': 'sum__num',
#     'viz_type': 'table'},
#    'id': 681,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "boy",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        "sum__num"\n    ],\n    "row_limit": 50,\n    "time_range": "100 years ago : now",\n    "timeseries_limit_metric": "sum__num",\n    "viz_type": "table"\n}',
#    'slice_name': 'Boys',
#    'slice_url': '/explore/?slice_id=681&form_data=%7B%22slice_id%22%3A%20681%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/681/thumbnail/371e5743af7af7067153250d76399e65/',
#    'url': '/explore/?slice_id=681',
#    'viz_type': 'table'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890937870.846,
#    'changed_on_utc': '2024-05-28T10:08:57.870846+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/675',
#    'form_data': {'compare_lag': '5',
#     'compare_suffix': 'over 5Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metric': 'sum__num',
#     'row_limit': 50000,
#     'slice_id': 675,
#     'time_range': '100 years ago : now',
#     'viz_type': 'big_number'},
#    'id': 675,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "5",\n    "compare_suffix": "over 5Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metric": "sum__num",\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "big_number"\n}',
#    'slice_name': 'Participants',
#    'slice_url': '/explore/?slice_id=675&form_data=%7B%22slice_id%22%3A%20675%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/675/thumbnail/016eb9b7d38ea17b0163b1741fd420b2/',
#    'url': '/explore/?slice_id=675',
#    'viz_type': 'big_number'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890937293.503,
#    'changed_on_utc': '2024-05-28T10:08:57.293503+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/678',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': ['other'],
#       'expressionType': 'SIMPLE',
#       'filterOptionName': '2745eae5',
#       'operator': 'NOT IN',
#       'subject': 'state'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['state'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': [{'aggregate': 'SUM',
#       'column': {'column_name': 'num_boys', 'type': 'BIGINT(20)'},
#       'expressionType': 'SIMPLE',
#       'label': 'Boys',
#       'optionName': 'metric_11'},
#      {'aggregate': 'SUM',
#       'column': {'column_name': 'num_girls', 'type': 'BIGINT(20)'},
#       'expressionType': 'SIMPLE',
#       'label': 'Girls',
#       'optionName': 'metric_12'}],
#     'row_limit': 50000,
#     'slice_id': 678,
#     'time_range': '100 years ago : now',
#     'viz_type': 'dist_bar'},
#    'id': 678,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": [\n                "other"\n            ],\n            "expressionType": "SIMPLE",\n            "filterOptionName": "2745eae5",\n            "operator": "NOT IN",\n            "subject": "state"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "state"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num_boys",\n                "type": "BIGINT(20)"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Boys",\n            "optionName": "metric_11"\n        },\n        {\n            "aggregate": "SUM",\n            "column": {\n                "column_name": "num_girls",\n                "type": "BIGINT(20)"\n            },\n            "expressionType": "SIMPLE",\n            "label": "Girls",\n            "optionName": "metric_12"\n        }\n    ],\n    "row_limit": 50000,\n    "time_range": "100 years ago : now",\n    "viz_type": "dist_bar"\n}',
#    'slice_name': 'Genders by State',
#    'slice_url': '/explore/?slice_id=678&form_data=%7B%22slice_id%22%3A%20678%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/678/thumbnail/99bac9d4fe9d58c4bf33672bbb8a3994/',
#    'url': '/explore/?slice_id=678',
#    'viz_type': 'dist_bar'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890937240.14,
#    'changed_on_utc': '2024-05-28T10:08:57.240140+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/680',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'girl',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': [],
#     'limit': '100',
#     'markup_type': 'markdown',
#     'metric': 'sum__num',
#     'rotation': 'square',
#     'row_limit': 50000,
#     'series': 'name',
#     'size_from': '10',
#     'size_to': '70',
#     'slice_id': 680,
#     'time_range': '100 years ago : now',
#     'viz_type': 'word_cloud'},
#    'id': 680,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "girl",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [],\n    "limit": "100",\n    "markup_type": "markdown",\n    "metric": "sum__num",\n    "rotation": "square",\n    "row_limit": 50000,\n    "series": "name",\n    "size_from": "10",\n    "size_to": "70",\n    "time_range": "100 years ago : now",\n    "viz_type": "word_cloud"\n}',
#    'slice_name': 'Girl Name Cloud',
#    'slice_url': '/explore/?slice_id=680&form_data=%7B%22slice_id%22%3A%20680%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/680/thumbnail/16f128caed6c0c6c7c4c9ffe6003ab9c/',
#    'url': '/explore/?slice_id=680',
#    'viz_type': 'word_cloud'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '18 minutes ago',
#    'changed_on_dttm': 1716890937190.268,
#    'changed_on_utc': '2024-05-28T10:08:57.190268+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': 'USA Births Names', 'id': 2}],
#    'datasource_id': 2,
#    'datasource_name_text': 'public.birth_names',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=2',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/679',
#    'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#       'comparator': 'girl',
#       'expressionType': 'SIMPLE',
#       'operator': '==',
#       'subject': 'gender'}],
#     'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'datasource': '2__table',
#     'granularity_sqla': 'ds',
#     'groupby': ['name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': ['sum__num'],
#     'row_limit': 50,
#     'slice_id': 679,
#     'time_range': '100 years ago : now',
#     'timeseries_limit_metric': 'sum__num',
#     'viz_type': 'table'},
#    'id': 679,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "adhoc_filters": [\n        {\n            "clause": "WHERE",\n            "comparator": "girl",\n            "expressionType": "SIMPLE",\n            "operator": "==",\n            "subject": "gender"\n        }\n    ],\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "granularity_sqla": "ds",\n    "groupby": [\n        "name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        "sum__num"\n    ],\n    "row_limit": 50,\n    "time_range": "100 years ago : now",\n    "timeseries_limit_metric": "sum__num",\n    "viz_type": "table"\n}',
#    'slice_name': 'Girls',
#    'slice_url': '/explore/?slice_id=679&form_data=%7B%22slice_id%22%3A%20679%7D',
#    'table': {'default_endpoint': None, 'table_name': 'birth_names'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/679/thumbnail/f5fea8d05a137c4a4e6c6d0be67327cd/',
#    'url': '/explore/?slice_id=679',
#    'viz_type': 'table'},
#   {'cache_timeout': None,
#    'certification_details': None,
#    'certified_by': None,
#    'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#    'changed_by_name': 'Superset Admin',
#    'changed_on_delta_humanized': '20 minutes ago',
#    'changed_on_dttm': 1716890828831.2732,
#    'changed_on_utc': '2024-05-28T10:07:08.831273+0000',
#    'created_by': None,
#    'created_by_name': '',
#    'created_on_delta_humanized': '21 minutes ago',
#    'dashboards': [{'dashboard_title': "World Bank's Data", 'id': 1}],
#    'datasource_id': 1,
#    'datasource_name_text': 'public.wb_health_population',
#    'datasource_type': 'table',
#    'datasource_url': '/explore/?datasource_type=table&datasource_id=1',
#    'description': None,
#    'description_markeddown': '',
#    'edit_url': '/chart/edit/666',
#    'form_data': {'compare_lag': '10',
#     'compare_suffix': 'o10Y',
#     'country_fieldtype': 'cca3',
#     'datasource': '1__table',
#     'entity': 'country_code',
#     'granularity_sqla': 'year',
#     'groupby': ['country_name'],
#     'limit': '25',
#     'markup_type': 'markdown',
#     'metrics': ['sum__SP_POP_TOTL'],
#     'row_limit': 50000,
#     'show_bubbles': True,
#     'slice_id': 666,
#     'time_range': '2014-01-01 : 2014-01-02',
#     'viz_type': 'table'},
#    'id': 666,
#    'is_managed_externally': False,
#    'last_saved_at': None,
#    'last_saved_by': None,
#    'owners': [],
#    'params': '{\n    "compare_lag": "10",\n    "compare_suffix": "o10Y",\n    "country_fieldtype": "cca3",\n    "entity": "country_code",\n    "granularity_sqla": "year",\n    "groupby": [\n        "country_name"\n    ],\n    "limit": "25",\n    "markup_type": "markdown",\n    "metrics": [\n        "sum__SP_POP_TOTL"\n    ],\n    "row_limit": 50000,\n    "show_bubbles": true,\n    "since": "2014-01-01",\n    "time_range": "2014-01-01 : 2014-01-02",\n    "until": "2014-01-02",\n    "viz_type": "table"\n}',
#    'slice_name': 'Most Populated Countries',
#    'slice_url': '/explore/?slice_id=666&form_data=%7B%22slice_id%22%3A%20666%7D',
#    'table': {'default_endpoint': None, 'table_name': 'wb_health_population'},
#    'tags': [],
#    'thumbnail_url': '/api/v1/chart/666/thumbnail/9fa8b9e870268e71447bda948a46b035/',
#    'url': '/explore/?slice_id=666',
#    'viz_type': 'table'}]}

# %%
#get example slice schema 
r5=requests.get(base_url+'/api/v1/chart/', headers=headersAuth)
tu=r5.json()['result'][0]['thumbnail_url']
tu
# Out:
# '/api/v1/chart/695/thumbnail/79fad41abb05b2206b12599d65164ee4/'

# %%
r6=requests.get(base_url+'/api/v1/chart/695/cache_screenshot/', headers=headersAuth)
r6.json()
# Out:
# {'cache_key': '679d1db44689b4b7c46bbb06de91f885',
#  'chart_url': 'http://superset_app:8088/superset/slice/695/',
#  'image_url': 'http://superset_app:8088/api/v1/chart/695/screenshot/679d1db44689b4b7c46bbb06de91f885/'}

# %%
r7=requests.get(base_url+'/api/v1/chart/695/thumbnail/679d1db44689b4b7c46bbb06de91f885/', headers=headersAuth)
print(f"{r7}, {r7.json()}")
# Out:
# <Response [202]>, {'message': 'OK Async'}
