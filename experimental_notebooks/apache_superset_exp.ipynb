# %%
import requests
import json
from IPython.display import JSON

# %%
#configs
#base_url = 'http://localhost:8088'
base_url ='http://carecognitics-superset.31g.co.uk/'

# %%
payload = {'username':'admin',
           'password':'admin',
           'provider':'db',
           'refresh': 'True'
           }
r = requests.post(base_url + '/api/v1/security/login', json=payload)

# %%
print(r.status_code)
# Out:
# 200

# %%
access_token = r.json()['access_token']
refresh_token = r.json()['refresh_token']
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJmcmVzaCI6dHJ1ZSwiaWF0IjoxNzE2Mzc1OTI4LCJqdGkiOiI1ZTg4ODZjMC04NDVhLTQ1YjQtODg0My0xNWFlOWRjNGY3OTQiLCJ0eXBlIjoiYWNjZXNzIiwic3ViIjoxLCJuYmYiOjE3MTYzNzU5MjgsImV4cCI6MTcxNjM3NjgyOH0.GDMBV_m96orhQ7CkaIiVs3CT2uVh7koaGG_WwwHfQVE'

# %%
headersAuth = {'Authorization':'Bearer ' + access_token}
headersAuth
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJmcmVzaCI6dHJ1ZSwiaWF0IjoxNzE2Mzc1OTI4LCJqdGkiOiI1ZTg4ODZjMC04NDVhLTQ1YjQtODg0My0xNWFlOWRjNGY3OTQiLCJ0eXBlIjoiYWNjZXNzIiwic3ViIjoxLCJuYmYiOjE3MTYzNzU5MjgsImV4cCI6MTcxNjM3NjgyOH0.GDMBV_m96orhQ7CkaIiVs3CT2uVh7koaGG_WwwHfQVE'}

# %% [markdown]
# ### CSRF Token

# %%
csrf_request=requests.get(base_url + '/api/v1/security/csrf_token/', headers=headersAuth)
csrf_token=csrf_request.json()['result']
print(csrf_request.status_code)
print(csrf_token)
# Out:
# 200
# IjQxNTgxOTE2OWY1OTk4MmZhNzQ2MjU5MWUxYjNiMzY5MTJiYmViYmIi.Zk3ReA.pqKFDmQM5l-IY27I4tKTry9Kxqo

# %%
headersAuth_1 = {'Authorization':'Bearer ' + csrf_token}
headersAuth_1
# Out:
# {'Authorization': 'Bearer IjQxNTgxOTE2OWY1OTk4MmZhNzQ2MjU5MWUxYjNiMzY5MTJiYmViYmIi.Zk3ReA.pqKFDmQM5l-IY27I4tKTry9Kxqo'}

# %% [markdown]
# ### GET List of Charts

# %%
r2 = requests.get(base_url+'/api/v1/chart/', headers=headersAuth)
resp_chart = r2.json()

# %%
JSON(resp_chart)

# %%
resp_chart['result']
# Out:
# [{'cache_timeout': None,
#   'certification_details': None,
#   'certified_by': None,
#   'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#   'changed_by_name': 'Superset Admin',
#   'changed_on_delta_humanized': '5 minutes ago',
#   'changed_on_dttm': 1716375584132.6958,
#   'changed_on_utc': '2024-05-22T10:59:44.132696+0000',
#   'created_by': None,
#   'created_by_name': '',
#   'created_on_delta_humanized': '27 minutes ago',
#   'dashboards': [{'dashboard_title': 'FCC New Coder Survey 2018', 'id': 5}],
#   'datasource_id': 10,
#   'datasource_name_text': 'public.FCC 2018 Survey',
#   'datasource_type': 'table',
#   'datasource_url': '/explore/?datasource_type=table&datasource_id=10',
#   'description': None,
#   'description_markeddown': '',
#   'edit_url': '/chart/edit/96',
#   'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#      'comparator': '0',
#      'expressionType': 'SIMPLE',
#      'filterOptionName': 'filter_3f8ug0vnqk1_oy0mvl0izdc',
# ...

# %%
for slice in resp_chart['result']:
    if slice['datasource_name_text'] == 'public.genre,eu,jp':
        print(slice)

# %%
r11 = requests.get(base_url+'/api/v1/dataset/', headers=headersAuth)
r11.json()
# for slice in r11.json()['result']:
#     if slice['id'] == 24:
#         print(slice)
# Out:
# {'count': 24,
#  'description_columns': {},
#  'ids': [24,
#   11,
#   17,
#   12,
#   10,
#   18,
#   2,
#   15,
#   13,
#   5,
#   19,
#   8,
#   6,
#   16,
#   4,
#   1,
#   3,
#   14,
#   9,
#   7],
#  'label_columns': {'changed_by.first_name': 'Changed By First Name',
#   'changed_by.last_name': 'Changed By Last Name',
#   'changed_by_name': 'Changed By Name',
#   'changed_on_delta_humanized': 'Changed On Delta Humanized',
#   'changed_on_utc': 'Changed On Utc',
#   'database.database_name': 'Database Database Name',
#   'database.id': 'Database Id',
#   'datasource_type': 'Datasource Type',
#   'default_endpoint': 'Default Endpoint',
#   'description': 'Description',
#   'explore_url': 'Explore Url',
#   'extra': 'Extra',
#   'id': 'Id',
#   'kind': 'Kind',
#   'owners.first_name': 'Owners First Name',
#   'owners.id': 'Owners Id',
#   'owners.last_name': 'Owners Last Name',
#   'schema': 'Schema',
#   'sql': 'Sql',
#   'table_name': 'Table Name'},
#  'list_columns': ['id',
# ...

# %% [markdown]
# ### GET List of databases

# %%
r3 = requests.get(base_url+'/api/v1/database/', headers=headersAuth)
resp = r3.json()

# %%
resp
# Out:
# {'count': 1,
#  'description_columns': {},
#  'ids': [1],
#  'label_columns': {'allow_ctas': 'Allow Ctas',
#   'allow_cvas': 'Allow Cvas',
#   'allow_dml': 'Allow Dml',
#   'allow_file_upload': 'Allow File Upload',
#   'allow_run_async': 'Allow Run Async',
#   'allows_cost_estimate': 'Allows Cost Estimate',
#   'allows_subquery': 'Allows Subquery',
#   'allows_virtual_table_explore': 'Allows Virtual Table Explore',
#   'backend': 'Backend',
#   'changed_by.first_name': 'Changed By First Name',
#   'changed_by.last_name': 'Changed By Last Name',
#   'changed_on': 'Changed On',
#   'changed_on_delta_humanized': 'Changed On Delta Humanized',
#   'created_by.first_name': 'Created By First Name',
#   'created_by.last_name': 'Created By Last Name',
#   'database_name': 'Database Name',
#   'disable_data_preview': 'Disable Data Preview',
#   'engine_information': 'Engine Information',
#   'explore_database_id': 'Explore Database Id',
#   'expose_in_sqllab': 'Expose In Sqllab',
# ...

# %% [markdown]
# ### Charts API

# %%
#get example slice schema 
r7=requests.get(base_url+'/api/v1/chart/', headers=headersAuth)
tu=r7.json()['result'][0]['thumbnail_url']
tu
# Out:
# '/api/v1/chart/96/thumbnail/8109d4edbb96ff9cf1b9377fb1f53847/'

# %%
r7.json()['result']
# Out:
# [{'cache_timeout': None,
#   'certification_details': None,
#   'certified_by': None,
#   'changed_by': {'first_name': 'Superset', 'last_name': 'Admin'},
#   'changed_by_name': 'Superset Admin',
#   'changed_on_delta_humanized': '5 minutes ago',
#   'changed_on_dttm': 1716375584132.6958,
#   'changed_on_utc': '2024-05-22T10:59:44.132696+0000',
#   'created_by': None,
#   'created_by_name': '',
#   'created_on_delta_humanized': '27 minutes ago',
#   'dashboards': [{'dashboard_title': 'FCC New Coder Survey 2018', 'id': 5}],
#   'datasource_id': 10,
#   'datasource_name_text': 'public.FCC 2018 Survey',
#   'datasource_type': 'table',
#   'datasource_url': '/explore/?datasource_type=table&datasource_id=10',
#   'description': None,
#   'description_markeddown': '',
#   'edit_url': '/chart/edit/96',
#   'form_data': {'adhoc_filters': [{'clause': 'WHERE',
#      'comparator': '0',
#      'expressionType': 'SIMPLE',
#      'filterOptionName': 'filter_3f8ug0vnqk1_oy0mvl0izdc',
# ...

# %%
r10=requests.get(base_url+tu, headers=headersAuth)
print(r10)
r10.json()
# Out:
# <Response [202]>
# {'message': 'OK Async'}

# %%
tu
# Out:
# '/api/v1/chart/96/thumbnail/8109d4edbb96ff9cf1b9377fb1f53847/'

# %%
#/api/v1/chart/96/screenshot/8109d4edbb96ff9cf1b9377fb1f53847/

# %%
r15=requests.get(base_url+'/api/v1/chart/96/screenshot/8109d4edbb96ff9cf1b9377fb1f53847/', headers=headersAuth)
print(r15)
r15.json()
# Out:
# <Response [404]>
# {'message': 'Not found'}

# %%
#creates a chart
null = None
r8=requests.post(base_url+'/api/v1/chart/', headers=headersAuth, json={"cache_timeout": null,
      "certification_details": null,
      "certified_by": null,
      "dashboards": [],
      "datasource_id": 25,
      "datasource_name": "public.genre,eu,jp",
      "datasource_type": "table",
      "description": 'null',
      "params": """{\"datasource\":\"1__table\",\"viz_type\":\"echarts_timeseries_bar\",\"x_axis\":\"genre\",\"time_grain_sqla\":\"P1D\",\"xAxisForceCategorical\":false,
      \"x_axis_sort_asc\":true,\"x_axis_sort_series\":\"name\",\"x_axis_sort_series_ascending\":true,\"metrics\":[{\"expressionType\":\"SIMPLE\",\"column\":{\"advanced_data_type\":null,
      \"certification_details\":null,\"certified_by\":null,\"column_name\":\"jp_sales\",\"description\":null,
      \"expression\":null,\"filterable\":true,\"groupby\":true,\"id\":null,\"is_certified\":false,\"is_dttm\":false,\"python_date_format\":null,\"type\":\"FLOAT\",\"type_generic\":0,
      \"verbose_name\":null,\"warning_markdown\":null},\"aggregate\":\"SUM\",\"sqlExpression\":null,\"datasourceWarning\":false,\"hasCustomLabel\":false,\"label\":\"Total Sales Cost in Japan\",
      \"optionName\":\"metric_na7nqv3jwcd_znuzdhquag\"},{\"expressionType\":\"SIMPLE\",\"column\":{\"advanced_data_type\":null,\"certification_details\":null,\"certified_by\":null,
      \"column_name\":\"eu_sales\",\"description\":null,\"expression\":null,\"filterable\":true,\"groupby\":true,\"id\":null,\"is_certified\":false,\"is_dttm\":false,\"python_date_format\":null,
      \"type\":\"FLOAT\",\"type_generic\":0,\"verbose_name\":null,\"warning_markdown\":null},\"aggregate\":\"SUM\",\"sqlExpression\":null,\"datasourceWarning\":false,\"hasCustomLabel\":false,
      \"label\":\"Total Sales Cost in the EU\",\"optionName\":\"metric_ztiitd2b78q_1v0gmbvii2u\"}],\"groupby\":[],\"adhoc_filters\":[],\"order_desc\":true,\"row_limit\":10000,\"truncate_metric\":true,
      \"show_empty_columns\":true,\"comparison_type\":\"values\",\"annotation_layers\":[],\"forecastPeriods\":10,\"forecastInterval\":0.8,\"orientation\":\"vertical\",\"x_axis_title_margin\":15,
      \"y_axis_title_margin\":15,\"y_axis_title_position\":\"Left\",\"sort_series_type\":\"sum\",\"color_scheme\":\"supersetColors\",\"only_total\":true,\"show_legend\":true,
      \"legendType\":\"scroll\",\"legendOrientation\":\"top\",\"x_axis_time_format\":\"smart_date\",\"y_axis_format\":\"SMART_NUMBER\",\"truncateXAxis\":true,\"y_axis_bounds\":[null,null],
      \"rich_tooltip\":true,\"tooltipTimeFormat\":\"smart_date\",\"extra_form_data\":{},\"dashboards\":[]}""",
      "slice_name": "Popularity for Total Sales of Different video game genres",
       "viz_type": "echarts_timeseries_bar"}
              )
r8.json()
# Out:
# {'message': {'datasource_id': ['Datasource does not exist']}}

# %%
#displays the chart

# %% [markdown]
# ### SQL Lab API

# %%
requests.post(
    base_url+ '/api/v1/saved_query/',
    headers=headersAuth,
    json={
  "db_id": 1,
  "description": "An SQL query to get genre, eu sales and jp sales in 2014",
  "label": "",
  "schema": "public",
  "sql": "SELECT genre, eu_sales, jp_sales FROM video_game_sales WHERE year=2014",
  "template_parameters": ""
}).json()
# Out:
# {'id': 3,
#  'result': {'db_id': 1,
#   'description': 'An SQL query to get genre, eu sales and jp sales in 2014',
#   'label': '',
#   'schema': 'public',
#   'sql': 'SELECT genre, eu_sales, jp_sales FROM video_game_sales WHERE year=2014',
#   'template_parameters': ''}}

# %%
r5 = requests.post(
    base_url+ '/api/v1/sqllab/estimate/',
    headers=headersAuth,
    json={
  "database_id": 1,
  "schema": "public",
  "sql": "SELECT gender, name, num FROM birth_names",
  "template_params": {}
}



)
result = r5.json()
print(result)
# Out:
# {'result': [{'Start-up cost': '0.0', 'Total cost': '1537.91'}]}

# %%
r4 = requests.post(
    base_url+ '/api/v1/sqllab/execute/',
    headers=headersAuth,
    json={
  "client_id": 'a2dc77af-e654-49bb-b321-40f6b559a1ee',
  "ctas_method": "string",
  "database_id": 1,
  "expand_data": 'True',
  "json": 'True',
  "queryLimit": 0,
  "runAsync": 'True',
  "schema": "public",
  "select_as_cta": 'True',
  "sql": "SELECT gender, name, num FROM birth_names",
  "sql_editor_id": "0",
  "tab": "",
  "templateParams": "",
  "tmp_table_name": ""
}

    

)
result = r4.json()
print(result)
# Out:
# {'errors': [{'error_type': 'GENERIC_DB_ENGINE_ERROR', 'message': 'Create failed'}]}

# %%
requests.get(
    base_url+ '/api/v1/sqllab/results/',
    headers=headersAuth,
    json={'key':access_token})
# Out:
# <Response [400]>

# %%
requests.get(
    base_url+ '/api/v1/sqllab/export//',
    headers=headersAuth,)
# Out:
# <Response [404]>
